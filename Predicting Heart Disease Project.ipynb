# %% [markdown]
# # Problem Statement –
# **You are the Data Scientist at a medical research facility. The facility wants you to build a machine
# learning model to classify if given the data of a patient should tell if the patient is at risk of heart
# attack**

# %% [markdown]
# # Tasks to be done:
# # A) Data Analysis:
# **a. Import the dataset**

# %%
import pandas as pd

hd = pd.read_csv("C:\\New folder\\Input Practice Dataset files CSV Excel\\dataset.csv")
hd.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# **b. Get information about dataset (mean, max, min, quartiles etc.)**

# %%
hd.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %% [markdown]
# **c. Find the correlation between all fields.**

# %%
hd.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trestbps  0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalach  -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exang     0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slope    -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# ca        0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thal      0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# ...

# %% [markdown]
# #### Explanation:
#
# - We import the pandas library and read the dataset from a CSV file.
# - We use the info() method to get a concise summary of the dataset, including the number of rows, data types, and memory usage.
# - We use the describe() method to get a summary of the central tendency and variability of the dataset.
# - We calculate the correlation matrix using the corr() method, which returns a matrix of pairwise correlation coefficients between all columns in the dataset.

# %% [markdown]
# # B) Data Visualization:
# **a. Visualize the number of patients having a heart disease and not having a heart disease.**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(x='target', data=hd)
plt.title('Number of Patients with and without Heart Disease')
plt.show()

# %% [markdown]
# **b. Visualize the age and weather patient has disease or not**

# %%
sns.scatterplot(data=hd, x='age', y='target')
plt.title('Age vs Heart Disease')
plt.show()

# %% [markdown]
# **c. Visualize correlation between all features using a heat map.**

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(hd.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# #### Explanation:
#
# - We import the matplotlib and seaborn libraries for data visualization.
# - We use countplot to visualize the number of patients with and without heart disease.
# - We use scatterplot to visualize the relationship between age and heart disease.
# - We use heatmap to visualize the correlation matrix, with annotations and a color map.

# %% [markdown]
# # C) Logistic Regression:
# **a. Build a simple logistic regression model.**
#
# **i. Divide the dataset in 70:30 ratio.**

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix

# Divide the dataset in 70:30 ratio
X = hd.drop('target', axis=1)
y = hd['target']

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %% [markdown]
# **ii. Build the model on train set and predict the values on test set.**

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
log_model = LogisticRegression(solver='liblinear')

log_model.fit(X_train,y_train)
y_pred1 = log_model.predict(X_test)

# %% [markdown]
# **iii. Build the confusion matrix and get the accuracy score.**

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

cm_log = confusion_matrix(y_test, y_pred1)
accuracy_log = accuracy_score(y_test, y_pred1)

print('Logistic Regression Confusion Matrix:\n', cm_log)
print('\nLogistic Regression Accuracy:', accuracy_log)

# %% [markdown]
# #### Explanation:
#
# - We import the necessary libraries for model selection, logistic regression, and metrics.
# - We divide the dataset into training and testing sets using train_test_split.
# - We build a simple logistic regression model using LogisticRegression.
# - We fit the model to the training data using fit.
# - We predict the values on the test set using predict.
# - We build the confusion matrix using confusion_matrix and calculate the accuracy score using accuracy_score.

# %% [markdown]
# # D) Decision Tree:
# **a. Build a decision tree model.**
#
# **i. Divide the dataset in 70:30 ratio.**

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
import graphviz

# Divide the dataset in 70:30 ratio
X = hd.drop('target', axis=1)
y = hd['target']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# **ii. Build the model on train set and predict the values on test set.**

# %%
dt_model = DecisionTreeClassifier()
dt_model.fit(X_train,y_train)
y_pred2 = dt_model.predict(X_test)

# %% [markdown]
# **iii. Build the confusion matrix and calculate the accuracy.**

# %%
cm_dt = confusion_matrix(y_test, y_pred2)
accuracy_dt = accuracy_score(y_test, y_pred2)

print('Decision Tree Confusion Matrix:\n', cm_dt)
print('\nDecision Tree Accuracy:', accuracy_dt)
# Out:
# Decision Tree Confusion Matrix:
#  [[32  9]
#  [17 33]]
#
# Decision Tree Accuracy: 0.7142857142857143

# %% [markdown]
# **iv. Visualize the decision tree using the graphviz package.**

# %%
from sklearn import tree
dot_data = tree.export_graphviz(dt_model, out_file=None, 
                                feature_names=X.columns, 
                                class_names=['No Disease', 'Disease'],
                                filled=True, rounded=True,
                                special_characters=True)

graph = graphviz.Source(dot_data)
graph.render("decision_tree")
# Out:
# 'decision_tree.pdf'

# %% [markdown]
# #### Explanation:
#
# - We import the necessary libraries for decision trees, metrics, and graphviz.
# - We divide the dataset into training and testing sets using train_test_split.
# - We build a decision tree model using DecisionTreeClassifier.
# - We fit the model to the training data using

# %% [markdown]
# # E) Random Forest:
# **a. Build a Random Forest model .**
#
# **i. Divide the dataset in 70:30 ratio.**

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
import graphviz

# Divide the dataset in 70:30 ratio
X = hd.drop('target', axis=1)
y = hd['target']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# **ii. Build the model on train set and predict the values on test set.**

# %%
rf_model = RandomForestClassifier()
rf_model.fit(X_train,y_train)
y_pred3 = rf_model.predict(X_test)

# %% [markdown]
# **iii. Build the confusion matrix and calculate the accuracy.**

# %%
cm_rf=confusion_matrix(y_test,y_pred3)
accuracy_rf = accuracy_score(y_test,y_pred3)

print('Random Forest Confusion Matrix:\n', cm_rf)
print('\nRandom Forest Accuracy:', accuracy_rf)
# Out:
# Random Forest Confusion Matrix:
#  [[32  9]
#  [10 40]]
#
# Random Forest Accuracy: 0.7912087912087912

# %% [markdown]
# **iv. Visualize the model using the graphviz package.**

# %%
from sklearn import tree

for i, estimator in enumerate(rf_model.estimators_):
    dot_data = tree.export_graphviz(estimator, out_file=None, 
                                    feature_names=X.columns,  
                                    class_names=['No Disease', 'Disease'],  
                                    filled=True, rounded=True,  
                                    special_characters=True)  
    print(f"Decision Tree {i+1}:")
    print(dot_data)
# Out:
# Decision Tree 1:
# digraph Tree {
# node [shape=box, style="filled, rounded", color="black", fontname="helvetica"] ;
# edge [fontname="helvetica"] ;
# 0 [label=<thal &le; 2.5<br/>gini = 0.494<br/>samples = 138<br/>value = [94, 118]<br/>class = Disease>, fillcolor="#d7ebfa"] ;
# 1 [label=<cp &le; 0.5<br/>gini = 0.409<br/>samples = 93<br/>value = [41, 102]<br/>class = Disease>, fillcolor="#89c4ef"] ;
# 0 -> 1 [labeldistance=2.5, labelangle=45, headlabel="True"] ;
# 2 [label=<ca &le; 0.5<br/>gini = 0.482<br/>samples = 33<br/>value = [31, 21]<br/>class = No Disease>, fillcolor="#f7d6bf"] ;
# 1 -> 2 ;
# 3 [label=<age &le; 63.5<br/>gini = 0.365<br/>samples = 18<br/>value = [6, 19]<br/>class = Disease>, fillcolor="#78bced"] ;
# 2 -> 3 ;
# 4 [label=<trestbps &le; 162.0<br/>gini = 0.397<br/>samples = 16<br/>value = [6, 16]<br/>class = Disease>, fillcolor="#83c2ef"] ;
# 3 -> 4 ;
# ...

# %% [markdown]
# # F) Select the best model
# **a. Print the confusion matrix of all classifiers.**

# %%
print('Logistic Regression Confusion Matrix:\n', cm_log)
print('\nDecision Tree Confusion Matrix:\n', cm_dt)
print('\nRandom Forest Confusion Matrix:\n', cm_rf)
# Out:
# Logistic Regression Confusion Matrix:
#  [[32  9]
#  [ 8 42]]
#
# Decision Tree Confusion Matrix:
#  [[32  9]
#  [17 33]]
#
# Random Forest Confusion Matrix:
#  [[32  9]
#  [10 40]]

# %% [markdown]
# **b. Print the classification report of all classifiers.**

# %%
from sklearn.metrics import classification_report
print('Classification Report of Logistic Regression:\n',classification_report(y_test,y_pred1))
print('\nClassification Report of Decision Tree:\n',classification_report(y_test,y_pred2))
print('\nClassification Report of Random Forest:\n',classification_report(y_test,y_pred3))
# Out:
# Classification Report of Logistic Regression:
#                precision    recall  f1-score   support
#
#            0       0.80      0.78      0.79        41
#            1       0.82      0.84      0.83        50
#
#     accuracy                           0.81        91
#    macro avg       0.81      0.81      0.81        91
# weighted avg       0.81      0.81      0.81        91
#
#
# Classification Report of Decision Tree:
#                precision    recall  f1-score   support
#
#            0       0.65      0.78      0.71        41
#            1       0.79      0.66      0.72        50
#
#     accuracy                           0.71        91
#    macro avg       0.72      0.72      0.71        91
# weighted avg       0.73      0.71      0.71        91
#
#
# Classification Report of Random Forest:
#                precision    recall  f1-score   support
#
#            0       0.76      0.78      0.77        41
#            1       0.82      0.80      0.81        50
#
# ...

# %% [markdown]
# **c. Calculate Recall Precision and F1 score of all the models.**

# %%
from sklearn.metrics import recall_score

print('Recall Score of Logistic Regression:',recall_score(y_test, y_pred1))
print('\nRecall Score of Decision Tree:',recall_score(y_test, y_pred2))
print('\nRecall Score of Random Forest:',recall_score(y_test, y_pred3))
# Out:
# Recall Score of Logistic Regression: 0.84
#
# Recall Score of Decision Tree: 0.66
#
# Recall Score of Random Forest: 0.8

# %%
from sklearn.metrics import precision_score

print('Precision Score of Logistic Regression :',precision_score(y_test, y_pred1))
print('\nPrecision Score of Decision Tree :',precision_score(y_test, y_pred2))
print('\nPrecision Score of Random Forest :',precision_score(y_test, y_pred3))
# Out:
# Precision Score of Logistic Regression : 0.8235294117647058
#
# Precision Score of Decision Tree : 0.7857142857142857
#
# Precision Score of Random Forest : 0.8163265306122449

# %%
from sklearn.metrics import f1_score

print('F1 Score of Logistic Regression:',f1_score(y_test, y_pred1))
print('\nF1 Score of Decision Tree :',f1_score(y_test, y_pred2))
print('\nF1 Score of Random Forest :',f1_score(y_test, y_pred3))
# Out:
# F1 Score of Logistic Regression: 0.8316831683168315
#
# F1 Score of Decision Tree : 0.717391304347826
#
# F1 Score of Random Forest : 0.8080808080808082

# %% [markdown]
# **d. Visualize confusion matrix using heatmaps.**

# %%
sns.heatmap(cm_log, annot=True, cmap='BuPu')
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(cm_dt, annot=True, cmap='BuGn')
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(cm_rf, annot=True, cmap='rocket')
# Out:
# <AxesSubplot:>

# %% [markdown]
# **e. Select the best model based on the best accuracies.**

# %%
print('Logistic Regression Accuracy:', accuracy_log)
print('\nDecision Tree Accuracy:', accuracy_dt)
print('\nRandom Forest Accuracy:', accuracy_rf)
# Out:
# Logistic Regression Accuracy: 0.8131868131868132
#
# Decision Tree Accuracy: 0.7142857142857143
#
# Random Forest Accuracy: 0.7912087912087912
